# %% [markdown]
# # **Statistics Part 2** **Theory**

# %% [markdown]
# 1. What is hypothesis testing in statistics?
#
# Hypothesis testing is a statistical method used to make decisions or inferences about population parameters based on sample data. It helps determine whether a certain assumption (hypothesis) about the population is likely to be true.
#
# We begin by forming two hypotheses:
#
# Null hypothesis (H₀): Assumes no effect or no difference.
#
# Alternative hypothesis (H₁ or Ha): Assumes an effect or difference exists.
#
# Based on sample data, we use statistical tests to determine whether there is enough evidence to reject the null hypothesis in favor of the alternative.

# %% [markdown]
# 2. What is the null hypothesis, and how does it differ from the alternative hypothesis?
#
# The null hypothesis (H₀) is a statement of no effect, no difference, or status quo. It is the hypothesis we test against.
#
# The alternative hypothesis (H₁ or Ha) is a statement that contradicts the null hypothesis and represents what we aim to prove.
#
# Difference:
#
# H₀ is assumed true until proven otherwise.
#
# H₁ is accepted only if there is sufficient evidence against H₀.
#
# Example:
#
# H₀: The average battery life is 10 hours.
#
# H₁: The average battery life is not 10 hours.

# %% [markdown]
# 3. What is the significance level in hypothesis testing, and why is it important?
#
# The significance level (denoted as α) is the probability of rejecting the null hypothesis when it is actually true. It defines the threshold for how extreme the test results must be to reject H₀.
#
# Common values: 0.05 (5%), 0.01 (1%)
#
# It is important because it controls the Type I error rate—the risk of making a false positive conclusion.
#
# Example:
# If α = 0.05, we are willing to accept a 5% chance of incorrectly rejecting H₀.

# %% [markdown]
# 4. What does a P-value represent in hypothesis testing?
#
# The P-value is the probability of obtaining a test statistic equal to or more extreme than the observed value, assuming that the null hypothesis is true.
#
# It tells us how likely the observed data is under the assumption that H₀ is correct.
#
# A smaller P-value indicates stronger evidence against H₀.

# %% [markdown]
# 5. How do you interpret the P-value in hypothesis testing?
#
# If P-value ≤ α (significance level) → Reject the null hypothesis.
#
# If P-value > α → Fail to reject the null hypothesis.
#
# Example:
#
# If the P-value is 0.03 and α = 0.05, we reject H₀ because the result is statistically significant.
#
# If P-value is 0.08 and α = 0.05, we do not reject H₀.

# %% [markdown]
# 6. What are Type 1 and Type 2 errors in hypothesis testing?
#
# Type 1 Error (α): Rejecting the null hypothesis when it is actually true.
#
# Example: Saying a drug works when it actually doesn’t.
#
# Type 2 Error (β): Failing to reject the null hypothesis when it is actually false.
#
# Example: Saying a drug doesn't work when it actually does.

# %% [markdown]
# 7. What is the difference between a one-tailed and a two-tailed test in hypothesis testing?
#
# One-tailed test: Tests for the possibility of the effect in only one direction.
#
# H₁: μ > 50 or H₁: μ < 50
#
# Two-tailed test: Tests for the possibility of the effect in both directions.
#
# H₁: μ ≠ 50
#
# Key difference:
#
# One-tailed is more powerful if direction is known.
#
# Two-tailed is safer when we’re unsure of direction.

# %% [markdown]
# 8. What is the Z-test, and when is it used in hypothesis testing?
#
# A Z-test is used when:
#
# The sample size is large (n > 30)
#
# Population standard deviation is known
#
# Data follows a normal distribution
#
# It is commonly used to compare:
#
# Sample mean vs population mean
#
# Proportions
#
# Example: Testing if the average height of students in a college differs from the national average.

# %% [markdown]
# 9. How do you calculate the Z-score, and what does it represent in hypothesis testing?
# Formula:
#
# 𝑍
# =
# 𝑋
# ˉ
# −
# 𝜇/
# 𝜎
# /
# 𝑛
#
#
# Where:ˉ
#
# X
# ˉ
#  : Sample mean
#
#
# μ: Population mean
#
#
# σ: Population standard deviation
#
#
# n: Sample size
#
# The Z-score represents how many standard deviations the sample mean is away from the population mean. It helps determine whether the sample result is statistically significant.

# %% [markdown]
# 10. What is the T-distribution, and when should it be used instead of the normal distribution?
#
# The T-distribution is a probability distribution used when:
#
# The sample size is small (n < 30)
#
# The population standard deviation is unknown
#
# It is similar to the normal distribution but has fatter tails, meaning it accounts for more variability in smaller samples.
#
# Use T-distribution when:
#
# You're testing means from a small sample
#
# You don’t know the population standard deviation
#
# As the sample size increases, the T-distribution approaches the normal distribution.

# %% [markdown]
# 11. What is the difference between a Z-test and a T-test?
#
# | Feature              | Z-test                              | T-test                             |
# | -------------------- | ----------------------------------- | ---------------------------------- |
# | Sample Size          | Large (n > 30)                      | Small (n ≤ 30)                     |
# | Population Std. Dev. | Known                               | Unknown                            |
# | Distribution Used    | Normal distribution                 | T-distribution                     |
# | Example              | Testing known population proportion | Testing sample mean vs. population |

# %% [markdown]
# 12. What is the T-test, and how is it used in hypothesis testing?
#
# The T-test is used to determine whether there is a significant difference between:
#
# A sample mean and population mean (one-sample)
#
# Two sample means (two-sample)
#
# Paired observations (paired T-test)
#
# Types:
#
# One-sample T-test
#
# Independent two-sample T-test
#
# Paired T-test

# %% [markdown]
# 13. What is the relationship between Z-test and T-test in hypothesis testing?
#
# Both are used to test hypotheses about means
#
# The main difference lies in sample size and knowledge of population standard deviation
#
# They give similar results for large samples
#
# As sample size increases, T-distribution converges to normal, so T-test becomes like Z-test

# %% [markdown]
# 14. What is a confidence interval, and how is it used to interpret statistical results?
#
# A confidence interval (CI) gives a range of values within which the true population parameter is expected to lie, with a certain level of confidence (e.g., 95%).
#
# Example: A 95% CI for mean = [48.5, 51.2]
# Means we are 95% confident that the population mean lies between 48.5 and 51.2.
#
# It provides more information than a single value estimate by showing margin of uncertainty.

# %% [markdown]
# 15. What is the margin of error, and how does it affect the confidence interval?
#
# The margin of error (MoE) is the maximum expected difference between the true population value and a sample estimate.
#
# Formula:
#
# Margin of Error
# =
# 𝑍
# 𝛼
# /
# 2
# ×
# 𝜎
# 𝑛
# ​
#
# A larger margin of error results in a wider confidence interval
#
# A smaller MoE means a more precise estimate
#
# Factors affecting MoE:
#
# Sample size (n ↑ → MoE ↓)
#
# Confidence level (higher CL → wider interval)
#
# Standard deviation

# %% [markdown]
# 16. How is Bayes’ Theorem used in statistics, and what is its significance?
#
# Bayes’ Theorem is used to find the probability of an event based on prior knowledge or information.
#
# Formula:
#
# 𝑃
# (
# 𝐴
# ∣
# 𝐵
# )
# =
# 𝑃
# (
# 𝐵
# ∣
# 𝐴
# )
# ⋅
# 𝑃
# (
# 𝐴
# )
# /
# 𝑃
# (
# 𝐵
# )
#
# Applications:
#
# Medical testing (true vs false positives)
#
# Spam filters
#
# Machine learning classification

# %% [markdown]
# 17. What is the Chi-square distribution, and when is it used?
#
# The Chi-square (χ²) distribution is used when:
#
# Data is categorical
#
# You want to test relationships between variables
#
# Uses:
#
# Goodness of fit test
#
# Test of independence
#
# Variance tests

# %% [markdown]
# 18. What is the Chi-square goodness of fit test, and how is it applied?
# The Chi-square goodness of fit test checks whether observed frequencies match expected frequencies.
#
# Steps:
#
# Define hypotheses:
#
# H₀: Observed = Expected
#
# H₁: Observed ≠ Expected
#
# Calculate:
#
# 𝜒
# 2
# =
# ∑
# (
# 𝑂
# −
# 𝐸
# )
# 2
# 𝐸
#
# Compare χ² value with critical value.

# %% [markdown]
# 19. What is the F-distribution, and when is it used in hypothesis testing?
#
# The F-distribution is used to compare two variances and is the basis for ANOVA (Analysis of Variance).
#
# Characteristics:
#
# Positively skewed
#
# Defined by two degrees of freedom: numerator and denominator
#
# Use cases:
#
# Testing equality of variances (F-test)
#
# ANOVA for comparing more than two means

# %% [markdown]
# 20. What is an ANOVA test, and what are its assumptions?
#
# ANOVA (Analysis of Variance) compares means of three or more groups to see if at least one group mean is different.
#
# Hypotheses:
#
# H₀: All group means are equal
#
# H₁: At least one group mean is different
#
# Assumptions:
#
# Independence of observations
#
# Normality of data within groups
#
# Equal variances across groups (homogeneity)

# %% [markdown]
# 21. What are the different types of ANOVA tests?
#
# One-way ANOVA: One independent variable with 3+ levels/groups
#
# Two-way ANOVA: Two independent variables, can also test interaction effect
#
# Repeated Measures ANOVA: Same subjects tested multiple times (within-subject design)
#
# MANOVA: Multivariate ANOVA for multiple dependent variables

# %% [markdown]
# 22. What is the F-test, and how does it relate to hypothesis testing?
#
# The F-test is used to compare two variances or to check the overall significance in ANOVA.
#
# Use in hypothesis testing:
#
# H₀: Variances are equal or group means are equal
#
# H₁: At least one variance or mean differs
#
# It helps in model evaluation, especially in regression and ANOVA.

# %% [markdown]
# # **Practical Part 1**

# %% [markdown]
# 1. Generate a random variable and display its value

# %%
import random

# Generate a random variable between 0 and 1
random_variable = random.random()
print("Random variable value:", random_variable)
# Out:
# Random variable value: 0.6148320434534724

# %% [markdown]
#  2. Generate a discrete uniform distribution and plot PMF

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate 1000 samples from a discrete uniform distribution (1 to 6)
data = np.random.randint(1, 7, size=1000)

# Calculate the unique values and their frequencies
values, counts = np.unique(data, return_counts=True)

# Calculate the Probability Mass Function (PMF)
pmf = counts / counts.sum()

# Plot the PMF
plt.stem(values, pmf)  # Removed use_line_collection
plt.xlabel("Value")
plt.ylabel("Probability")
plt.title("PMF of Discrete Uniform Distribution (1 to 6)")
plt.ylim(0, max(pmf) + 0.05)
plt.grid(True)
plt.show()

# %% [markdown]
# Q3. Calculate the probability density function (PDF) of a Bernoulli distribution using Python.

# %%
from scipy.stats import bernoulli

# Define probability of success
p = 0.7

# Values of the random variable (0 = failure, 1 = success)
x = [0, 1]

# Calculate the PMF (since Bernoulli is discrete, we use pmf not pdf)
pmf = bernoulli.pmf(x, p)

# Display the results
for val, prob in zip(x, pmf):
    print(f"P(X = {val}) = {prob}")
# Out:
# P(X = 0) = 0.30000000000000004
# P(X = 1) = 0.7

# %% [markdown]
#  Q4. Simulate a binomial distribution with n = 10, p = 0.5 and plot its histogram.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom

# Parameters
n = 10
p = 0.5

# Generate data
data = binom.rvs(n=n, p=p, size=1000)

# Plot histogram
plt.hist(data, bins=range(0, 12), align='left', edgecolor='black')
plt.xlabel("Number of Successes")
plt.ylabel("Frequency")
plt.title("Binomial Distribution (n=10, p=0.5)")
plt.grid(True)
plt.show()

# %% [markdown]
# Q5- Create a Poisson distribution and visualize it using Python

# %%
from scipy.stats import poisson

# Mean (lambda)
mu = 4

# Generate Poisson-distributed data
data = poisson.rvs(mu, size=1000)

# Plot histogram
plt.hist(data, bins=range(0, 12), align='left', edgecolor='black')
plt.xlabel("Number of Events")
plt.ylabel("Frequency")
plt.title("Poisson Distribution (λ = 4)")
plt.grid(True)
plt.show()

# %% [markdown]
# Q6-Write a Python program to calculate and plot the cumulative distribution function (CDF) of a discrete uniform distribution

# %%
from scipy.stats import randint
import numpy as np
import matplotlib.pyplot as plt

# Values from a discrete uniform distribution (1 to 6)
x = np.arange(1, 7)

# Calculate CDF
cdf = randint.cdf(x, 1, 7)  # randint is exclusive on upper bound

# Plot
plt.step(x, cdf, where='post')
plt.xlabel("Value")
plt.ylabel("CDF")
plt.title("CDF of Discrete Uniform Distribution (1 to 6)")
plt.grid(True)
plt.show()

# %% [markdown]
# Q7. Generate a continuous uniform distribution using NumPy and visualize it.

# %%
# Generate data from continuous uniform distribution between 0 and 1
data = np.random.uniform(0, 1, size=1000)

# Plot histogram
plt.hist(data, bins=20, edgecolor='black')
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.title("Continuous Uniform Distribution")
plt.grid(True)
plt.show()

# %% [markdown]
# Q8. Simulate data from a normal distribution and plot its histogram.

# %%
# Normal distribution parameters
mean = 0
std = 1

# Generate data
data = np.random.normal(loc=mean, scale=std, size=1000)

# Plot histogram
plt.hist(data, bins=30, edgecolor='black')
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.title("Normal Distribution Histogram (μ=0, σ=1)")
plt.grid(True)
plt.show()

# %% [markdown]
# Q9-Write a Python function to calculate Z-scores from a dataset and plot them

# %%
def plot_z_scores(data):
    mean = np.mean(data)
    std = np.std(data)
    z_scores = (data - mean) / std

    # Plot histogram of Z-scores
    plt.hist(z_scores, bins=30, edgecolor='black')
    plt.xlabel("Z-score")
    plt.ylabel("Frequency")
    plt.title("Histogram of Z-scores")
    plt.grid(True)
    plt.show()

# Example usage
sample_data = np.random.normal(loc=100, scale=15, size=1000)
plot_z_scores(sample_data)

# %% [markdown]
# Q10- Implement the Central Limit Theorem (CLT) using Python for a non-normal distribution

# %%
def simulate_clt(sample_size=30, num_samples=1000):
    sample_means = []

    for _ in range(num_samples):
        # Use exponential distribution to show CLT (non-normal)
        sample = np.random.exponential(scale=2.0, size=sample_size)
        sample_means.append(np.mean(sample))

    # Plot histogram of sample means
    plt.hist(sample_means, bins=30, edgecolor='black')
    plt.xlabel("Sample Mean")
    plt.ylabel("Frequency")
    plt.title(f"Central Limit Theorem (Sample Size = {sample_size})")
    plt.grid(True)
    plt.show()

# Run the simulation
simulate_clt()

# %% [markdown]
# Q11- Simulate multiple samples from a normal distribution and verify the Central Limit Theorem

# %%
import numpy as np
import matplotlib.pyplot as plt

sample_means = []

# Simulate 1000 samples, each of size 50, from normal distribution
for _ in range(1000):
    sample = np.random.normal(loc=50, scale=10, size=50)
    sample_means.append(np.mean(sample))

# Plot distribution of sample means
plt.hist(sample_means, bins=30, edgecolor='black')
plt.xlabel("Sample Mean")
plt.ylabel("Frequency")
plt.title("Central Limit Theorem Verification")
plt.grid(True)
plt.show()

# %% [markdown]
# 12. Write a Python function to calculate and plot the standard normal distribution (mean = 0, std = 1).

# %%
from scipy.stats import norm

x = np.linspace(-4, 4, 1000)
y = norm.pdf(x, 0, 1)

plt.plot(x, y)
plt.title("Standard Normal Distribution (μ=0, σ=1)")
plt.xlabel("x")
plt.ylabel("Probability Density")
plt.grid(True)
plt.show()

# %% [markdown]
# 13. Generate random variables and calculate their probabilities using the binomial distribution.

# %%
from scipy.stats import binom

n = 10
p = 0.5
x = np.arange(0, n+1)
probabilities = binom.pmf(x, n, p)

for i, prob in zip(x, probabilities):
    print(f"P(X={i}) = {prob}")
# Out:
# P(X=0) = 0.0009765624999999989
# P(X=1) = 0.009765625000000002
# P(X=2) = 0.04394531250000004
# P(X=3) = 0.1171875
# P(X=4) = 0.2050781249999999
# P(X=5) = 0.24609375000000003
# P(X=6) = 0.2050781249999999
# P(X=7) = 0.11718749999999999
# P(X=8) = 0.04394531250000004
# P(X=9) = 0.009765625000000002
# P(X=10) = 0.0009765625

# %% [markdown]
# 14. Calculate the Z-score for a data point and compare it to a standard normal distribution.

# %%
data_point = 75
mean = 70
std = 10

z_score = (data_point - mean) / std
print("Z-score:", z_score)

# Compare with standard normal
prob = norm.cdf(z_score)
print("P(X <= 75):", prob)
# Out:
# Z-score: 0.5
# P(X <= 75): 0.6914624612740131

# %% [markdown]
# 15. Implement hypothesis testing using Z-statistics for a sample dataset.

# %%
sample = np.random.normal(52, 8, 50)
sample_mean = np.mean(sample)
pop_mean = 50
pop_std = 8
n = len(sample)

z = (sample_mean - pop_mean) / (pop_std / np.sqrt(n))
p_value = 1 - norm.cdf(z)

print("Z-statistic:", z)
print("P-value (one-tailed):", p_value)
# Out:
# Z-statistic: 2.7306010669525818
# P-value (one-tailed): 0.0031609472852184295

# %% [markdown]
# 16. Create a confidence interval for a dataset using Python and interpret the result

# %%
import scipy.stats as stats

data = np.random.normal(100, 15, 100)
mean = np.mean(data)
std_err = stats.sem(data)

confidence = 0.95
ci = stats.t.interval(confidence, len(data)-1, loc=mean, scale=std_err)

print(f"95% Confidence Interval: {ci}")
# Out:
# 95% Confidence Interval: (np.float64(96.70636848791617), np.float64(102.13117140604174))

# %% [markdown]
# 17. Generate data from a normal distribution, then calculate and interpret the confidence interval for its mean.

# %%
data = np.random.normal(60, 10, 100)
mean = np.mean(data)
std_err = stats.sem(data)

conf = 0.99
ci = stats.t.interval(conf, len(data)-1, loc=mean, scale=std_err)

print("99% Confidence Interval:", ci)
# Out:
# 99% Confidence Interval: (np.float64(58.143804744877265), np.float64(63.288637180318354))

# %% [markdown]
# 18. Calculate and visualize the PDF of a normal distribution.

# %%
x = np.linspace(30, 90, 1000)
y = norm.pdf(x, loc=60, scale=10)

plt.plot(x, y)
plt.xlabel("x")
plt.ylabel("Density")
plt.title("Normal Distribution PDF (μ=60, σ=10)")
plt.grid(True)
plt.show()

# %% [markdown]
# 19. Use Python to calculate and interpret the CDF of a Poisson distribution.

# %%
from scipy.stats import poisson

mu = 3
x = np.arange(0, 11)
cdf = poisson.cdf(x, mu)

for val, prob in zip(x, cdf):
    print(f"P(X <= {val}) = {prob}")
# Out:
# P(X <= 0) = 0.04978706836786395
# P(X <= 1) = 0.1991482734714558
# P(X <= 2) = 0.42319008112684364
# P(X <= 3) = 0.6472318887822313
# P(X <= 4) = 0.8152632445237722
# P(X <= 5) = 0.9160820579686966
# P(X <= 6) = 0.9664914646911588
# P(X <= 7) = 0.9880954961436426
# P(X <= 8) = 0.996197007938324
# P(X <= 9) = 0.9988975118698845
# P(X <= 10) = 0.9997076630493527

# %% [markdown]
# 20. Simulate a random variable using continuous uniform distribution and calculate expected value.

# %%
data = np.random.uniform(10, 20, 1000)
expected_value = np.mean(data)

print("Expected Value (mean):", expected_value)
# Out:
# Expected Value (mean): 15.208448670022637

# %% [markdown]
# 21. Compare the standard deviations of two datasets and visualize the difference.

# %%
data1 = np.random.normal(100, 5, 1000)
data2 = np.random.normal(100, 20, 1000)

std1 = np.std(data1)
std2 = np.std(data2)

print("Standard Deviation of Data 1:", std1)
print("Standard Deviation of Data 2:", std2)

plt.hist(data1, bins=30, alpha=0.5, label='Low Std Dev')
plt.hist(data2, bins=30, alpha=0.5, label='High Std Dev')
plt.legend()
plt.title("Comparison of Standard Deviations")
plt.grid(True)
plt.show()
# Out:
# Standard Deviation of Data 1: 4.904533132752285
# Standard Deviation of Data 2: 20.11873168083998

# %% [markdown]
# 22. Calculate range and interquartile range (IQR) of a dataset.

# %%
data = np.random.normal(70, 15, 1000)

range_val = np.max(data) - np.min(data)
q1 = np.percentile(data, 25)
q3 = np.percentile(data, 75)
iqr = q3 - q1

print("Range:", range_val)
print("IQR:", iqr)
# Out:
# Range: 94.47126384227835
# IQR: 20.186222928989636

# %% [markdown]
# 23. Implement Z-score normalization on a dataset and visualize transformation.

# %%
data = np.random.normal(100, 20, 1000)
z_scores = (data - np.mean(data)) / np.std(data)

plt.hist(z_scores, bins=30, edgecolor='black')
plt.title("Z-score Normalized Data")
plt.xlabel("Z-score")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# %% [markdown]
#  24. Calculate skewness and kurtosis of a normal dataset.

# %%
from scipy.stats import skew, kurtosis

data = np.random.normal(100, 15, 1000)

print("Skewness:", skew(data))
print("Kurtosis:", kurtosis(data))
# Out:
# Skewness: -0.05049500752719695
# Kurtosis: -0.1300725884167231

# %% [markdown]
# # **Practical Part 2**

# %% [markdown]
# Q1. Perform a Z-test comparing sample mean to population mean and interpret results

# %%
from scipy import stats
import numpy as np

# Sample data
sample = np.random.normal(loc=52, scale=10, size=50)
sample_mean = np.mean(sample)
pop_mean = 50
pop_std = 10
n = len(sample)

# Z-test formula
z = (sample_mean - pop_mean) / (pop_std / np.sqrt(n))
p_value = 2 * (1 - stats.norm.cdf(abs(z)))

print("Z-value:", z)
print("P-value:", p_value)
# Out:
# Z-value: 0.5666771665058109
# P-value: 0.5709335368185611

# %% [markdown]
# Q2. Simulate data for hypothesis testing and calculate p-value

# %%
# Simulate 100 data points
data = np.random.normal(100, 15, 100)

# H0: mean = 100, H1: mean ≠ 100
t_stat, p_val = stats.ttest_1samp(data, 100)

print("T-statistic:", t_stat)
print("P-value:", p_val)
# Out:
# T-statistic: 0.3174961125186517
# P-value: 0.7515358467463308

# %% [markdown]
# Q3. One-sample Z-test: compare sample mean with population mean

# %%
sample = np.random.normal(98, 12, 40)
sample_mean = np.mean(sample)
pop_mean = 100
pop_std = 15

z = (sample_mean - pop_mean) / (pop_std / np.sqrt(len(sample)))
p_val = 2 * (1 - stats.norm.cdf(abs(z)))

print("Z-score:", z)
print("P-value:", p_val)
# Out:
# Z-score: -0.13445100083016823
# P-value: 0.8930459548674323

# %% [markdown]
# Q4. Two-tailed Z-test with decision region visualization

# %%
import matplotlib.pyplot as plt

z_score = z
alpha = 0.05
z_critical = stats.norm.ppf(1 - alpha / 2)

x = np.linspace(-4, 4, 1000)
y = stats.norm.pdf(x)

plt.plot(x, y)
plt.axvline(z_critical, color='red', linestyle='--', label='Critical Region')
plt.axvline(-z_critical, color='red', linestyle='--')
plt.axvline(z_score, color='blue', label='Z Score')
plt.title("Two-Tailed Z-Test Decision Region")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Q5. Function to calculate & visualize Type 1 and Type 2 errors

# %%
def visualize_errors(mu0, mu1, sigma, n, alpha=0.05):
    z_critical = stats.norm.ppf(1 - alpha)
    x = np.linspace(mu0 - 4*sigma, mu1 + 4*sigma, 1000)

    plt.plot(x, stats.norm.pdf(x, mu0, sigma/np.sqrt(n)), label='H0 Distribution')
    plt.plot(x, stats.norm.pdf(x, mu1, sigma/np.sqrt(n)), label='H1 Distribution')

    cutoff = mu0 + z_critical * (sigma / np.sqrt(n))
    plt.axvline(cutoff, color='red', linestyle='--', label='Critical Value')

    plt.fill_between(x, 0, stats.norm.pdf(x, mu0, sigma/np.sqrt(n)), where=(x >= cutoff), alpha=0.3, label='Type I Error')
    plt.fill_between(x, 0, stats.norm.pdf(x, mu1, sigma/np.sqrt(n)), where=(x < cutoff), alpha=0.3, label='Type II Error')

    plt.legend()
    plt.title("Type I and Type II Error Visualization")
    plt.grid(True)
    plt.show()

visualize_errors(mu0=100, mu1=105, sigma=15, n=30)

# %% [markdown]
# Q6. Perform independent T-test and interpret results

# %%
group1 = np.random.normal(60, 10, 30)
group2 = np.random.normal(65, 10, 30)

t_stat, p_val = stats.ttest_ind(group1, group2)

print("T-statistic:", t_stat)
print("P-value:", p_val)
# Out:
# T-statistic: -2.3672739061133257
# P-value: 0.021277003346701302

# %% [markdown]
#  Q7. Paired sample T-test and visualize

# %%
before = np.random.normal(80, 10, 30)
after = before + np.random.normal(2, 3, 30)

t_stat, p_val = stats.ttest_rel(before, after)

print("T-statistic:", t_stat)
print("P-value:", p_val)

plt.plot(before, label='Before')
plt.plot(after, label='After')
plt.legend()
plt.title("Paired Sample Comparison")
plt.grid(True)
plt.show()
# Out:
# T-statistic: -3.790586862392431
# P-value: 0.0007042503309926552

# %% [markdown]
# Q8. Simulate data and compare Z-test vs T-test

# %%
sample = np.random.normal(100, 15, 25)
pop_mean = 100
pop_std = 15

# Z-test
z = (np.mean(sample) - pop_mean) / (pop_std / np.sqrt(len(sample)))
p_z = 2 * (1 - stats.norm.cdf(abs(z)))

# T-test
t_stat, p_t = stats.ttest_1samp(sample, pop_mean)

print("Z-test: Z =", z, "P =", p_z)
print("T-test: T =", t_stat, "P =", p_t)
# Out:
# Z-test: Z = 1.5537604626447887 P = 0.12024156472853575
# T-test: T = 1.0306952663821272 P = 0.3129594345026629

# %% [markdown]
#  Q9. Function to calculate confidence interval for sample mean

# %%
def confidence_interval(data, confidence=0.95):
    mean = np.mean(data)
    sem = stats.sem(data)
    interval = stats.t.interval(confidence, len(data)-1, loc=mean, scale=sem)
    return interval

data = np.random.normal(50, 10, 40)
print("Confidence Interval:", confidence_interval(data))
# Out:
# Confidence Interval: (np.float64(48.098056879932024), np.float64(54.25077664481905))

# %% [markdown]
#  Q10. Calculate margin of error for confidence level

# %%
data = np.random.normal(70, 12, 100)
confidence = 0.95

sem = stats.sem(data)
margin_error = stats.t.ppf((1 + confidence) / 2, len(data)-1) * sem

print("Margin of Error:", margin_error)
# Out:
# Margin of Error: 2.227896514498296

# %% [markdown]
#  Q11. Implement Bayesian inference using Bayes’ Theorem

# %%
# P(A|B) = [P(B|A) * P(A)] / P(B)

def bayes_theorem(p_b_given_a, p_a, p_b):
    return (p_b_given_a * p_a) / p_b

# Example: medical test
p_disease = 0.01
p_positive_given_disease = 0.99
p_positive = 0.05

p_disease_given_positive = bayes_theorem(p_positive_given_disease, p_disease, p_positive)
print("P(Disease | Positive Test):", p_disease_given_positive)
# Out:
# P(Disease | Positive Test): 0.198

# %% [markdown]
# 12. Chi-square test for independence

# %%
from scipy.stats import chi2_contingency

# Contingency table
table = [[30, 10],
         [20, 40]]

chi2, p, dof, expected = chi2_contingency(table)
print("Chi-square Statistic:", chi2)
print("P-value:", p)
# Out:
# Chi-square Statistic: 15.041666666666666
# P-value: 0.00010516355403363098

# %% [markdown]
# Q13. Calculate expected frequencies for Chi-square

# %%
observed = np.array([[20, 30], [25, 25]])
_, _, _, expected = stats.chi2_contingency(observed)

print("Expected Frequencies:")
print(expected)
# Out:
# Expected Frequencies:
# [[22.5 27.5]
#  [22.5 27.5]]

# %% [markdown]
#  Q14. Goodness-of-fit test: compare observed with expected

# %%
observed = np.array([18, 22, 20, 25, 15])
expected = np.array([20, 20, 20, 20, 20])

chi2, p_val = stats.chisquare(f_obs=observed, f_exp=expected)

print("Chi-square Statistic:", chi2)
print("P-value:", p_val)
# Out:
# Chi-square Statistic: 2.9
# P-value: 0.5746972058298043
